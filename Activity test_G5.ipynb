# %%
# Import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the excel file into a pandas dataframe.
df = pd.read_excel("Dataset_w6.xlsx")

# %%
# Diplay the dataset
df
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %%
# summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   country                                     196 non-null    object
#  1   Region                                      196 non-null    object
#  2   Surface area (km2)                          196 non-null    int64
#  3   Population in thousands (2017)              196 non-null    int64
#  4   GDP per capita (current US$)                196 non-null    float64
#  5   Agricultural production index               196 non-null    int64
#  6   International trade: Imports (million US$)  196 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 10.8+ KB

# %% [markdown]
# This dataset contains the following data
#
# - there is 196 rows and 7 features.
# - this dataset has 196 countries with follows regions, surface area, population in thousands, GDP per capita, agricultural production and International trade: Imports features.

# %% [markdown]
# Before jump into the questions we first check the dataset

# %%
# Calculating the null values present in each columns in the dataset

df.isna().sum() # or you can use df.isnull().sum() as well
# Out:
# country                                       0
# Region                                        0
# Surface area (km2)                            0
# Population in thousands (2017)                0
# GDP per capita (current US$)                  0
# Agricultural production index                 0
# International trade: Imports (million US$)    0
# dtype: int64

# %% [markdown]
# As you can see that, there is no missing values present in the dataset. so we can move to the questions

# %% [markdown]
# ### 1. Find out how many countries are there in the dataset.

# %%
df['country'].count() # here only checking the country column count
# Out:
# 196

# %% [markdown]
# As per the dataset, we can clearly see that 196 rows are there. So here only checking the column count but we need to check unique countries present in this dataset.

# %%
# column with unique values in the dataset
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China, Hong Kong SAR', 'China, Macao SAR', 'China',
#        'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica',
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
# checking the number of unique elements in the country
df['country'].nunique()
# Out:
# 196

# %%
# percentage view of value_counts on country 
df['country'].value_counts(normalize = True)
# Out:
# Paraguay                0.005102
# Cambodia                0.005102
# Russian Federation      0.005102
# Papua New Guinea        0.005102
# Guyana                  0.005102
#                           ...
# Rwanda                  0.005102
# New Caledonia           0.005102
# Belarus                 0.005102
# Afghanistan             0.005102
# United Arab Emirates    0.005102
# Name: country, Length: 196, dtype: float64

# %% [markdown]
# Sometimes, getting a percentage count is better than the normal count. By setting **normalize=True,** the object returned will contain the relative frequencies of the unique values. The normalize parameter is set to **False** by default. **So we can cleary say that, there are 196 countries in the dataset**

# %% [markdown]
# ### 2. Examine the data by using visualizations.

# %%
# checking the columns in the dataset
df.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'GDP per capita (current US$)',
#        'Agricultural production index ',
#        'International trade: Imports (million US$)'],
#       dtype='object')

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Using pairpot, you can see the relation between the entire dataset. And here the histogram allow us to see the distribution of a single varibale while the scatter plots shows the relationship between two variables.

# %%
# correlation matrix
df.corr()
# Out:
#                                             Surface area (km2)  \
# Surface area (km2)                                    1.000000
# Population in thousands (2017)                        0.448362
# GDP per capita (current US$)                          0.064154
# Agricultural production index                         0.086247
# International trade: Imports (million US$)            0.482636
#
#                                             Population in thousands (2017)  \
# Surface area (km2)                                                0.448362
# Population in thousands (2017)                                    1.000000
# GDP per capita (current US$)                                     -0.051922
# Agricultural production index                                     0.121782
# International trade: Imports (million US$)                        0.532012
#
#                                             GDP per capita (current US$)  \
# ...

# %%
# correlation heatmap
sns.heatmap(df.corr(), cmap='coolwarm')
plt.show()

# %% [markdown]
# Using heatmap, it is represent the data correlation values as colors in the gragh based on some sort of gradient scale and red color means positive, blue means negative. The stronger the color, the larger the correlation magnitude.

# %%
# checking the top 10 population country in the dataset
top_10 = df.sort_values('Population in thousands (2017)', ascending=False).head(10)
top_10
# Out:
#                       country             Region  Surface area (km2)  \
# 39                      China        EasternAsia             9600000
# 82                      India       SouthernAsia             3287263
# 187  United States of America    NorthernAmerica             9833517
# 83                  Indonesia  South-easternAsia             1910931
# 23                     Brazil       SouthAmerica             8515767
# 132                  Pakistan       SouthernAsia              796095
# 129                   Nigeria      WesternAfrica              923768
# 12                 Bangladesh       SouthernAsia              147570
# 145        Russian Federation      EasternEurope            17098246
# 114                    Mexico     CentralAmerica             1964375
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 39                          1409517                        8109.1
# 82                          1339180                        1614.2
# ...

# %%
# Data visualization of the top 10 population country in the dataset

fig=plt.subplots(figsize=(16,4))
x = range(10)
plt.bar(x, top_10['Population in thousands (2017)'] / 10 ** 4)

plt.xticks(x, top_10.country, rotation = 'vertical') #plt.xticks(coordinates, actual string values, show this lables vertically)

plt.title('10 Most Populous Countries in 2017')
plt.ylabel('Population in thousands')
plt.show()

# %% [markdown]
# The above chart shows that, China is having the highest with above 140 thousand populations and India is the second highest with above 130 thousand populations.

# %%
# checking the least 10 population country in the dataset
least_10 = df.sort_values('Population in thousands (2017)', ascending=True).head(10)
least_10
# Out:
#                     country           Region  Surface area (km2)  \
# 118              Montserrat        Caribbean                 103
# 181                  Tuvalu        Polynesia                  26
# 43             Cook Islands        Polynesia                 236
# 133                   Palau       Micronesia                 459
# 24   British Virgin Islands        Caribbean                 151
# 111        Marshall Islands       Micronesia                 181
# 147   Saint Kitts and Nevis        Caribbean                 261
# 72                Greenland  NorthernAmerica             2166086
# 18                  Bermuda  NorthernAmerica                  53
# 33           Cayman Islands        Caribbean                 264
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 118                               5                       11553.4
# 181                              11                        3362.4
# ...

# %%
# Data visualization of the least 10 population country in the dataset

fig=plt.subplots(figsize=(16,4))
x = range(10)
plt.bar(x, least_10['Population in thousands (2017)'])

plt.xticks(x, least_10.country, rotation = 'vertical') #plt.xticks(coordinates, actual string values, show this lables vertically)

plt.title('10 Least Populous Countries in 2017')
plt.ylabel('Population in thousands')
plt.show()

# %% [markdown]
# This chart shows that, Montserrat is having the lowest with above 5 thousand populations and Tuvalu is the second lowest with above 11 thousand populations.

# %%
# Data visualization of the Region wise Population in the dataset

fig=plt.subplots(figsize=(16,4))
plt.xticks(rotation=90)
sns.barplot(x='Region',y=df['Population in thousands (2017)'] / 10**4,data=df)
plt.title('Region wise Population')
plt.show()

# %% [markdown]
# The region wise population, where Eastern Asia is the highest one and second is the Southern Asia. The lowest population in regions are Caribbean, Polynesia, Melanesia and Micronesia.

# %%
# Data visualization of the Population in Surface area in the dataset

plt.figure(figsize=(14,6))
plt.scatter(df['Surface area (km2)'],df['Population in thousands (2017)']/10**4,s=14,c='green',marker='^')
plt.title('Population in Surface area')
plt.xlabel('Surface area (km2)')
plt.ylabel('Population in thousands (2017)')
plt.show()

# %% [markdown]
# As you can see that less surface area with high populations and high surface area with less populations

# %% [markdown]
# ### 3. Find out how many countries with respect to the region are available in the dataset

# %%
# calculate the countries with respect to the region 
data = df.groupby('Region')['country'].count().sort_values()
data
# Out:
# Region
# Oceania               2
# NorthernAmerica       4
# Micronesia            4
# SouthernAfrica        5
# CentralAsia           5
# Polynesia             5
# NorthernAfrica        5
# Melanesia             5
# WesternEurope         7
# EasternAsia           7
# CentralAmerica        8
# SouthernAsia          9
# MiddleAfrica          9
# EasternEurope        10
# NorthernEurope       10
# South-easternAsia    11
# SouthAmerica         12
# SouthernEurope       12
# WesternAfrica        15
# Caribbean            16
# EasternAfrica        17
# WesternAsia          18
# Name: country, dtype: int64

# %%
#checking the length of the data
len(data)
# Out:
# 22

# %% [markdown]
# As you can see, there are 22 regions, amoung the 18 countries with highest number of same western Asia region and 2 countries with least number of same Oceania region.**so we can clearly say that 196 countries with respect to 22 regions are available in the dataset**

# %% [markdown]
# ### 4. On average which region has the highest

# %% [markdown]
# **a. GDP per capita (current US$)**

# %%
# display the dataset
df.head()
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia              652864
# 1              Albania  SouthernEurope               28748
# 2              Algeria  NorthernAfrica             2381741
# 3               Angola    MiddleAfrica             1246700
# 4  Antigua and Barbuda       Caribbean                 442
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                           35530                         623.2
# 1                            2930                        3984.2
# 2                           41318                        4154.1
# 3                           29784                        4714.1
# 4                             102                       14764.5
#
#    Agricultural production index   International trade: Imports (million US$)
# 0                             125                                        3568
# ...

# %%
# calculate the mean of GDP per capita with respect to region
region_GDP = df.groupby('Region')['GDP per capita (current US$)'].mean().round(2).sort_values()
region_GDP
# Out:
# Region
# WesternAfrica         1013.14
# EasternAfrica         2088.85
# SouthernAsia          2968.40
# MiddleAfrica          3928.83
# NorthernAfrica        3934.96
# SouthernAfrica        4191.90
# CentralAsia           4329.88
# Micronesia            5008.30
# CentralAmerica        6348.14
# SouthAmerica          8499.78
# Polynesia             8686.52
# Melanesia             9261.96
# EasternEurope         9292.49
# South-easternAsia    10299.03
# SouthernEurope       14462.74
# Caribbean            15135.56
# WesternAsia          17013.94
# EasternAsia          27967.61
# NorthernEurope       42098.22
# Oceania              44823.25
# WesternEurope        55387.13
# NorthernAmerica      57659.00
# Name: GDP per capita (current US$), dtype: float64

# %%
#display the bottom values in the dataset
region_GDP.tail(1)
# Out:
# Region
# NorthernAmerica    57659.0
# Name: GDP per capita (current US$), dtype: float64

# %%
# Data visualization of the Average of GDP per capita in the dataset

fig= plt.subplots(figsize=(16,4))
plt.xticks(rotation=90)
ax=sns.lineplot(data=region_GDP, markers=True,color='green')
ax.set(ylabel='GDP per capita Mean')
ax.set(title='Average of GDP per capita')
plt.show()

# %% [markdown]
# From the graph, on average Northern America region has the highest GDP per capita with mean 57659

# %% [markdown]
# **b. International trade: Imports (million US$)**

# %%
# calculate the mean of GDP per capita with respect to region
region_trade = df.groupby('Region')['International trade: Imports (million US$)'].mean().round(2).sort_values()
region_trade
# Out:
# Region
# Micronesia               99.00
# Polynesia               432.00
# Melanesia              2896.40
# Caribbean              3057.31
# MiddleAfrica           4381.22
# EasternAfrica          4726.18
# WesternAfrica          4898.33
# CentralAsia           12063.40
# SouthernAfrica        18005.60
# SouthAmerica          32885.67
# NorthernAfrica        35034.40
# WesternAsia           46025.56
# CentralAmerica        57031.50
# SouthernAsia          58199.33
# SouthernEurope        76666.67
# EasternEurope         85243.90
# South-easternAsia     98324.64
# Oceania              112914.50
# NorthernEurope       113407.20
# WesternEurope        407498.43
# EasternAsia          451995.00
# NorthernAmerica      663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %%
#display the bottom values in the dataset
region_trade.tail(1)
# Out:
# Region
# NorthernAmerica    663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %%
# Data visualization of the Average of International Trade: Imports in the dataset

fig= plt.subplots(figsize=(16,4))
plt.xticks(rotation=90)
ax=sns.lineplot(data=region_trade, markers=True, color='violet')
ax.set(ylabel='International Trade: Imports Mean')
ax.set(title='Average of International Trade: Imports')
plt.show()

# %% [markdown]
# on average Northern America region has the highest International trade: imports with mean 663552.25

# %% [markdown]
# ### 5. Find out which region has more consistent with respect to GDP per capita (current US$

# %%
# calculate the standard deviation of GDP per capita with respect to region
consistent_region = df.groupby('Region')['GDP per capita (current US$)'].std().round(2).sort_values()
consistent_region
# Out:
# Region
# WesternAfrica          815.10
# NorthernAfrica         974.71
# SouthernAfrica        2177.55
# SouthernAsia          2855.71
# EasternAfrica         3716.13
# CentralAsia           4152.22
# CentralAmerica        4180.44
# SouthAmerica          4273.71
# Micronesia            4820.67
# MiddleAfrica          5274.85
# EasternEurope         5415.49
# Polynesia             6956.25
# Oceania               9233.33
# SouthernEurope        9541.70
# Melanesia            13855.84
# Caribbean            14579.37
# South-easternAsia    16311.81
# WesternAsia          18812.15
# NorthernEurope       20671.03
# WesternEurope        24770.47
# NorthernAmerica      25749.62
# EasternAsia          27485.12
# Name: GDP per capita (current US$), dtype: float64

# %%
#display the topmost two values in the dataset
consistent_region.head(2)
# Out:
# Region
# WesternAfrica     815.10
# NorthernAfrica    974.71
# Name: GDP per capita (current US$), dtype: float64

# %%
# Data visualization of the Standard Deviation of GDP per capita in the dataset

fig= plt.subplots(figsize=(16,4))
plt.xticks(rotation=90)
ax=sns.lineplot(data=consistent_region, markers=True,color='blue')
ax.set(ylabel='Standard Deviation of GDP per capita' )
ax.set(title='Standard Deviation of GDP per capita')
plt.show()

# %% [markdown]
# Western Africa has more consistent with respect to GDP per capita (current US$) and Northern Africa follows the slighly same it's because closer to the Western Africa. And Eastern asia is the least consistency
